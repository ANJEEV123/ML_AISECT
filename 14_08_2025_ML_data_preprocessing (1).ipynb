# %%
#import pandas to run dataset
import pandas as pd

# %%
# load the makaan_dataset
dataset=pd.read_csv("/content/Makaan_data_700pages.csv")

# %%
# show the dataset information
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        14000 non-null  int64
#  1   Size              14000 non-null  int64
#  2   Size_unit         14000 non-null  object
#  3   Property_type     14000 non-null  object
#  4   Location          14000 non-null  object
#  5   Seller_name       14000 non-null  object
#  6   Seller_type       14000 non-null  object
#  7   Rent_price        14000 non-null  object
#  8   Area_sqft         14000 non-null  int64
#  9   Status            14000 non-null  object
#  10  Security_deposit  14000 non-null  object
#  11  Bathroom          6217 non-null   float64
#  12  Facing_direction  2924 non-null   object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.4+ MB

# %%
# remove the column unnamed
dataset = dataset.drop('Unnamed: 0', axis=1)

# %%
#remove the column facing_direction
dataset=dataset.drop('Facing_direction',axis=1)

# %%
#remove the column seller_name
dataset=dataset.drop('Seller_name',axis=1)

# %%
#add the two columns size, size_unit naming bhk
dataset['BHK'] = dataset['Size'].astype(str) + dataset['Size_unit']

# %%
#remove the column Size ,Size_unit
dataset = dataset.drop(['Size',	'Size_unit'], axis=1)

# %%
# Replace any repeated 'BHK' with just one 'BHK'
dataset['BHK'] = dataset['BHK'].str.replace(r'(BHK)+$', 'BHK', regex=True)

# %%
#Replace any repeated 'apartment' with just one 'apartment'
dataset['Property_type'] = dataset['Property_type'].str.replace(r'(Apartment)+$', 'Apartment', regex=True)

# %%
# change the crore words to float
dataset['Security_deposit'] = (dataset['Security_deposit'].astype(str).str.strip().str.replace(',', '', regex=False).str.replace(r'^[Nn]o$', '0', regex=True).str.replace(r'(\d+(\.\d+)?)\s*[Ll]', lambda m: str(float(m.group(1)) * 100000), regex=True).str.replace(r'(\d+(\.\d+)?)\s*[Cc]r', lambda m: str(float(m.group(1)) * 10000000),  regex=True).astype(float))

# %%
# change the lakhs to float
dataset['Rent_price'] = (dataset['Rent_price'].astype(str).str.strip().str.replace(',', '', regex=False).str.replace(r'^[Nn]o$', '0', regex=True).str.replace(r'(\d+(\.\d+)?)\s*[Ll]', lambda m: str(float(m.group(1)) * 100000), regex=True).str.replace(r'(\d+(\.\d+)?)\s*[Cc]r', lambda m: str(float(m.group(1)) * 10000000),  regex=True).astype(float))

# %%
# Replace all NaN values with 0
dataset = dataset.fillna(0)

# %%
dataset
# Out:
#            Property_type            Location     Seller_type  Rent_price  \
# 0      Independent Floor         Uttam Nagar  Verified Owner      8500.0
# 1      Independent House          Model Town  Verified Owner     48000.0
# 2              Apartment    Sector 13 Rohini  Verified Owner     20000.0
# 3              Apartment           DLF Farms  Verified Owner     11000.0
# 4      Independent Floor         laxmi nagar  Verified Owner     20000.0
# ...                  ...                 ...             ...         ...
# 13995  Independent Floor  Greater Kailash II           Agent    235000.0
# 13996  Independent Floor  Greater Kailash II           Agent    301000.0
# 13997  Independent Floor  Greater Kailash II           Agent    235000.0
# 13998  Independent Floor  Greater Kailash II           Agent    235000.0
# 13999  Independent Floor  Greater Kailash II           Agent    235000.0
#
#        Area_sqft          Status  Security_deposit  Bathroom   BHK
# ...

# %%
# Run the column
dataset.columns
# Out:
# Index(['Property_type', 'Location', 'Seller_type', 'Rent_price', 'Area_sqft',
#        'Status', 'Security_deposit', 'Bathroom', 'BHK'],
#       dtype='object')

# %%
#import labelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
#transforming the property_tyoe
dataset['Property_type'] = le.fit_transform(dataset['Property_type'])

# %%
#transforming the status
dataset['Status'] = le.fit_transform(dataset['Status'])

# %%
#transforming the bhk
dataset['BHK'] = le.fit_transform(dataset['BHK'])

# %%
##transforming the location
dataset['Location'] = le.fit_transform(dataset['Location'])

# %%
#transforming the seller_type
dataset['Seller_type'] = le.fit_transform(dataset['Seller_type'])

# %%
dataset
# Out:
#        Property_type  Location  Seller_type  Rent_price  Area_sqft  Status  \
# 0                  1       344            3      8500.0        500       1
# 1                  2       170            3     48000.0       1020       0
# 2                  0       265            3     20000.0        810       2
# 3                  0        46            3     11000.0        750       1
# 4                  1       375            3     20000.0       1300       0
# ...              ...       ...          ...         ...        ...     ...
# 13995              1        84            0    235000.0       3652       2
# 13996              1        84            0    301000.0       5562       2
# 13997              1        84            0    235000.0       2856       2
# 13998              1        84            0    235000.0       2856       2
# 13999              1        84            0    235000.0       2741       2
#
#        Security_deposit  Bathroom  BHK
# ...

# %%
#give the value for x
x = dataset[['Property_type', 'Location', 'Seller_type',
       'Area_sqft', 'Status', 'Security_deposit', 'Bathroom', 'BHK']]

# %%
x
# Out:
#        Property_type  Location  Seller_type  Area_sqft  Status  \
# 0                  1       344            3        500       1
# 1                  2       170            3       1020       0
# 2                  0       265            3        810       2
# 3                  0        46            3        750       1
# 4                  1       375            3       1300       0
# ...              ...       ...          ...        ...     ...
# 13995              1        84            0       3652       2
# 13996              1        84            0       5562       2
# 13997              1        84            0       2856       2
# 13998              1        84            0       2856       2
# 13999              1        84            0       2741       2
#
#        Security_deposit  Bathroom  BHK
# 0                   0.0       1.0    3
# 1                   0.0       3.0    4
# 2                   0.0       2.0    3
# 3                   0.0       1.0    4
# ...

# %%
#give the value for y
y= dataset['Rent_price']

# %%
y
# Out:
# 0          8500.0
# 1         48000.0
# 2         20000.0
# 3         11000.0
# 4         20000.0
#            ...
# 13995    235000.0
# 13996    301000.0
# 13997    235000.0
# 13998    235000.0
# 13999    235000.0
# Name: Rent_price, Length: 14000, dtype: float64

# %%
# import model selection for test split
from sklearn.model_selection import train_test_split

# %%
#train the dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
#import tree and metrices for get accuracy
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
#run the decision tree
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
#predict the values for decision tree
y_pred = dt.predict(x_test)
dt_r2 = r2_score(y_test, y_pred)

# %%
dt_r2
# Out:
# 0.9427836805920218

# %%
#import the random foest
from sklearn.ensemble import RandomForestRegressor

# %%
#run the randomforest
dt=RandomForestRegressor()
dt.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#predict the values for random forest
y_pred = dt.predict(x_test)
dt_r2 = r2_score(y_test, y_pred)

# %%
dt_r2
# Out:
# 0.9538439159504933

# %% [markdown]
# **classification decision_tree and randomForest **

# %%
import numpy as np
# Define price bins (adjust ranges as you want)
bins = [0, 10000, 25000, 50000, np.inf]  # 0-10k, 10k-25k, 25k-50k, >50k
labels = ['Low', 'Medium', 'High', 'Premium']

# %%
# Create classification target
dataset['Rent_class'] = pd.cut(dataset['Rent_price'], bins=bins, labels=labels)

# %%
# Encode class labels into integers
from sklearn.preprocessing import LabelEncoder
le_target = LabelEncoder()
dataset['Rent_class_encoded'] = le_target.fit_transform(dataset['Rent_class'])

# %%
# Features
X = dataset[['Property_type', 'Location', 'Seller_type', 'Area_sqft',
             'Status', 'Security_deposit', 'Bathroom', 'BHK']]

# %%
# Target (encoded class)
y = dataset['Rent_class_encoded']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred_dtc = dtc.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dtc))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dtc, target_names=labels))
# Out:
# Decision Tree Accuracy: 0.9096428571428572
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          Low       0.81      0.81      0.81       510
#       Medium       0.77      0.68      0.72       108
#         High       0.82      0.85      0.83       476
#      Premium       0.97      0.97      0.97      1706
#
#     accuracy                           0.91      2800
#    macro avg       0.84      0.83      0.83      2800
# weighted avg       0.91      0.91      0.91      2800

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200, random_state=0)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=0)

# %%
y_pred_rfc = rfc.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rfc))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rfc, target_names=labels))
# Out:
# Random Forest Accuracy: 0.9246428571428571
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          Low       0.85      0.83      0.84       510
#       Medium       0.84      0.65      0.73       108
#         High       0.82      0.89      0.86       476
#      Premium       0.98      0.98      0.98      1706
#
#     accuracy                           0.92      2800
#    macro avg       0.87      0.84      0.85      2800
# weighted avg       0.93      0.92      0.92      2800

# %%
# SVC (Support Vector Classifier)
from sklearn.svm import SVC

# %%
svc = SVC(kernel='rbf', C=10, gamma='scale', random_state=0)
svc.fit(X_train, y_train)
# Out:
# SVC(C=10, random_state=0)

# %%
y_pred_svc = svc.predict(X_test)

# %%
print("SVC Accuracy:", accuracy_score(y_test, y_pred_svc))
print("\nClassification Report (SVC):\n", classification_report(y_test, y_pred_svc, target_names=labels))
# Out:
# SVC Accuracy: 0.7057142857142857
#
# Classification Report (SVC):
#                precision    recall  f1-score   support
#
#          Low       0.62      0.13      0.21       510
#       Medium       0.00      0.00      0.00       108
#         High       0.37      0.97      0.53       476
#      Premium       1.00      0.85      0.92      1706
#
#     accuracy                           0.71      2800
#    macro avg       0.50      0.49      0.42      2800
# weighted avg       0.79      0.71      0.69      2800
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# Logistic Regression (Multiclass softmax)
# =======================================
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(max_iter=5000, multi_class='multinomial', solver='lbfgs', random_state=0)
log_reg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=5000, multi_class='multinomial', random_state=0)

# %%
y_pred_log = log_reg.predict(X_test)

# %%
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_log))
print("\nClassification Report (Logistic Regression):\n", classification_report(y_test, y_pred_log, target_names=labels))
# Out:
# Logistic Regression Accuracy: 0.8228571428571428
#
# Classification Report (Logistic Regression):
#                precision    recall  f1-score   support
#
#          Low       0.63      0.64      0.63       510
#       Medium       0.48      0.30      0.37       108
#         High       0.63      0.69      0.66       476
#      Premium       0.96      0.95      0.95      1706
#
#     accuracy                           0.82      2800
#    macro avg       0.67      0.64      0.65      2800
# weighted avg       0.82      0.82      0.82      2800
