# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [50, 100],           # small & standard
    'criterion': ['squared_error'],      # most common for regression
    'max_depth': [None, 10],             # unlimited vs shallow
    'min_samples_split': [2, 5],         # default vs stricter split
    'min_samples_leaf': [1, 2],          # default vs smoother tree
    'max_features': ['sqrt', None],      # common strategies
    'bootstrap': [True],                 # standard for RandomForest
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'criterion': ['squared_error'],
#                          'max_depth': [None, 10],
#                          'max_features': ['sqrt', None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# r2: 0.830785430626146

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 21       0.330359      0.014298         0.022194        0.001154
# 23       0.367295      0.024262         0.026114        0.002922
# 22       0.167692      0.003554         0.013130        0.000237
# 15       0.436604      0.015194         0.022097        0.001196
# 19       0.330113      0.011248         0.024315        0.004262
# 4        0.169552      0.004259         0.013617        0.001131
# 6        0.172480      0.006542         0.013349        0.000888
# 20       0.160520      0.003861         0.012625        0.000445
# 14       0.276474      0.069960         0.016878        0.009288
# 7        0.348046      0.017807         0.022989        0.000868
# 31       0.396138      0.042439         0.019849        0.003811
# 28       0.218761      0.011954         0.013817        0.001872
# 29       0.423918      0.015657         0.021779        0.001625
# 5        0.345969      0.010924         0.025763        0.003589
# 30       0.208147      0.005037         0.012304        0.000761
# 3        0.337506      0.008632         0.023362        0.002467
# 13       0.454125      0.010274         0.022195        0.000760
# 12       0.225022      0.004491         0.014839        0.001508
# 2        0.175959      0.009747         0.013097        0.000551
# 18       0.169866      0.008993         0.012256        0.000161
# 17       0.351577      0.017233         0.029065        0.010530
# 16       0.176278      0.003363         0.013966        0.001869
# 27       0.432816      0.014887         0.021224        0.000912
# 26       0.293427      0.069194         0.019400        0.008363
# 1        0.418298      0.012901         0.027465        0.005650
# 11       0.714408      0.129563         0.031163        0.009988
# 10       0.427536      0.045561         0.022382        0.004173
# 25       0.999172      0.149315         0.052230        0.021268
# 0        0.204255      0.003216         0.014735        0.000920
# 24       0.308173      0.042878         0.020991        0.008455
# 9        0.691557      0.126172         0.036941        0.012986
# 8        0.285492      0.017467         0.015952        0.001498
#
#     param_bootstrap param_criterion param_max_depth param_max_features  \
# 21             True   squared_error              10               sqrt
# 23             True   squared_error              10               sqrt
# 22             True   squared_error              10               sqrt
# 15             True   squared_error            None               None
# 19             True   squared_error              10               sqrt
# 4              True   squared_error            None               sqrt
# 6              True   squared_error            None               sqrt
# 20             True   squared_error              10               sqrt
# 14             True   squared_error            None               None
# 7              True   squared_error            None               sqrt
# 31             True   squared_error              10               None
# 28             True   squared_error              10               None
# 29             True   squared_error              10               None
# 5              True   squared_error            None               sqrt
# 30             True   squared_error              10               None
# 3              True   squared_error            None               sqrt
# 13             True   squared_error            None               None
# 12             True   squared_error            None               None
# 2              True   squared_error            None               sqrt
# 18             True   squared_error              10               sqrt
# 17             True   squared_error              10               sqrt
# 16             True   squared_error              10               sqrt
# 27             True   squared_error              10               None
# 26             True   squared_error              10               None
# 1              True   squared_error            None               sqrt
# 11             True   squared_error            None               None
# 10             True   squared_error            None               None
# 25             True   squared_error              10               None
# 0              True   squared_error            None               sqrt
# 24             True   squared_error              10               None
# 9              True   squared_error            None               None
# 8              True   squared_error            None               None
#
#     param_min_samples_leaf  param_min_samples_split  param_n_estimators  \
# 21                       2                        2                 100
# 23                       2                        5                 100
# 22                       2                        5                  50
# 15                       2                        5                 100
# 19                       1                        5                 100
# 4                        2                        2                  50
# 6                        2                        5                  50
# 20                       2                        2                  50
# 14                       2                        5                  50
# 7                        2                        5                 100
# 31                       2                        5                 100
# 28                       2                        2                  50
# 29                       2                        2                 100
# 5                        2                        2                 100
# 30                       2                        5                  50
# 3                        1                        5                 100
# 13                       2                        2                 100
# 12                       2                        2                  50
# 2                        1                        5                  50
# 18                       1                        5                  50
# 17                       1                        2                 100
# 16                       1                        2                  50
# 27                       1                        5                 100
# 26                       1                        5                  50
# 1                        1                        2                 100
# 11                       1                        5                 100
# 10                       1                        5                  50
# 25                       1                        2                 100
# 0                        1                        2                  50
# 24                       1                        2                  50
# 9                        1                        2                 100
# 8                        1                        2                  50
#
#                                                params  split0_test_score  \
# 21  {'bootstrap': True, 'criterion': 'squared_erro...           0.858012
# 23  {'bootstrap': True, 'criterion': 'squared_erro...           0.858466
# 22  {'bootstrap': True, 'criterion': 'squared_erro...           0.858988
# 15  {'bootstrap': True, 'criterion': 'squared_erro...           0.863292
# 19  {'bootstrap': True, 'criterion': 'squared_erro...           0.858806
# 4   {'bootstrap': True, 'criterion': 'squared_erro...           0.863681
# 6   {'bootstrap': True, 'criterion': 'squared_erro...           0.856766
# 20  {'bootstrap': True, 'criterion': 'squared_erro...           0.859496
# 14  {'bootstrap': True, 'criterion': 'squared_erro...           0.864130
# 7   {'bootstrap': True, 'criterion': 'squared_erro...           0.853513
# 31  {'bootstrap': True, 'criterion': 'squared_erro...           0.863100
# 28  {'bootstrap': True, 'criterion': 'squared_erro...           0.865407
# 29  {'bootstrap': True, 'criterion': 'squared_erro...           0.862362
# 5   {'bootstrap': True, 'criterion': 'squared_erro...           0.854434
# 30  {'bootstrap': True, 'criterion': 'squared_erro...           0.863094
# 3   {'bootstrap': True, 'criterion': 'squared_erro...           0.859287
# 13  {'bootstrap': True, 'criterion': 'squared_erro...           0.861193
# 12  {'bootstrap': True, 'criterion': 'squared_erro...           0.859903
# 2   {'bootstrap': True, 'criterion': 'squared_erro...           0.863235
# 18  {'bootstrap': True, 'criterion': 'squared_erro...           0.858220
# 17  {'bootstrap': True, 'criterion': 'squared_erro...           0.856572
# 16  {'bootstrap': True, 'criterion': 'squared_erro...           0.850574
# 27  {'bootstrap': True, 'criterion': 'squared_erro...           0.861773
# 26  {'bootstrap': True, 'criterion': 'squared_erro...           0.855570
# 1   {'bootstrap': True, 'criterion': 'squared_erro...           0.846926
# 11  {'bootstrap': True, 'criterion': 'squared_erro...           0.861811
# 10  {'bootstrap': True, 'criterion': 'squared_erro...           0.861160
# 25  {'bootstrap': True, 'criterion': 'squared_erro...           0.853681
# 0   {'bootstrap': True, 'criterion': 'squared_erro...           0.846257
# 24  {'bootstrap': True, 'criterion': 'squared_erro...           0.857641
# 9   {'bootstrap': True, 'criterion': 'squared_erro...           0.849304
# 8   {'bootstrap': True, 'criterion': 'squared_erro...           0.852464
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 21           0.836318           0.820886           0.852372
# 23           0.836003           0.822509           0.849931
# 22           0.835159           0.820810           0.848921
# 15           0.839108           0.811909           0.847502
# 19           0.836938           0.814856           0.850260
# 4            0.837143           0.811825           0.845886
# 6            0.840607           0.810443           0.848507
# 20           0.839641           0.816151           0.845585
# 14           0.833868           0.810503           0.846363
# 7            0.832516           0.819953           0.846244
# 31           0.830959           0.811666           0.844525
# 28           0.826426           0.808780           0.848223
# 29           0.833728           0.804435           0.848253
# 5            0.831889           0.823931           0.845569
# 30           0.832768           0.804766           0.844227
# 3            0.835819           0.816250           0.841029
# 13           0.835147           0.804690           0.845489
# 12           0.833282           0.803381           0.841742
# 2            0.833797           0.810609           0.839302
# 18           0.824047           0.813010           0.846925
# 17           0.825796           0.808519           0.843762
# 16           0.824921           0.810160           0.842377
# 27           0.832746           0.802119           0.828006
# 26           0.834334           0.804700           0.824097
# 1            0.828518           0.803050           0.840742
# 11           0.828840           0.798046           0.819186
# 10           0.825274           0.800706           0.828759
# 25           0.824569           0.802300           0.816566
# 0            0.823408           0.802476           0.836127
# 24           0.823994           0.801712           0.809173
# 9            0.820945           0.801152           0.816655
# 8            0.815040           0.797195           0.814035
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 21           0.786339         0.830785        0.025735                1
# 23           0.781620         0.829706        0.026981                2
# 22           0.782923         0.829360        0.026546                3
# 15           0.784153         0.829193        0.028013                4
# 19           0.782774         0.828727        0.027349                5
# 4            0.782373         0.828182        0.028354                6
# 6            0.783683         0.828001        0.027126                7
# 20           0.778084         0.827791        0.028525                8
# 14           0.782905         0.827554        0.028340                9
# 7            0.784991         0.827443        0.024154               10
# 31           0.785647         0.827179        0.026725               11
# 28           0.784553         0.826678        0.028493               12
# 29           0.783954         0.826546        0.028665               13
# 5            0.776771         0.826519        0.027028               14
# 30           0.787405         0.826452        0.027179               15
# 3            0.777229         0.825923        0.027943               16
# 13           0.781488         0.825601        0.028763               17
# 12           0.784448         0.824551        0.027122               18
# 2            0.775311         0.824451        0.029727               19
# 18           0.777633         0.823967        0.028168               20
# 17           0.775665         0.822063        0.028326               21
# 16           0.777343         0.821075        0.025963               22
# 27           0.775451         0.820019        0.029243               23
# 26           0.777377         0.819216        0.026590               24
# 1            0.770621         0.817972        0.028046               25
# 11           0.779939         0.817564        0.027872               26
# 10           0.771534         0.817486        0.029961               27
# 25           0.773512         0.814126        0.026340               28
# 0            0.762141         0.814082        0.029802               29
# 24           0.767630         0.812030        0.029358               30
# 9            0.771024         0.811816        0.025651               31
# 8            0.765751         0.808897        0.028145               32

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
