# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None, 20],
    'max_features': ['sqrt'],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [None, 20],
#                          'max_features': ['sqrt'], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# r2: 0.8296832028752489

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.557788      0.099599         0.031361        0.010287
# 14       0.264518      0.027690         0.017394        0.008164
# 13       0.367969      0.043323         0.027433        0.006445
# 5        0.341762      0.016061         0.021873        0.000576
# 7        0.322073      0.016527         0.021894        0.000716
# 12       0.163633      0.002796         0.013056        0.001075
# 4        0.174621      0.008120         0.014176        0.001264
# 3        0.331203      0.016964         0.024191        0.001746
# 6        0.161337      0.003356         0.012776        0.000487
# 11       0.331545      0.010886         0.022605        0.001548
# 10       0.169696      0.014098         0.012381        0.000151
# 2        0.174585      0.011895         0.013319        0.000919
# 9        0.389865      0.006980         0.025168        0.003475
# 1        0.395240      0.013825         0.024794        0.001733
# 0        0.206265      0.016029         0.013488        0.000633
# 8        0.203762      0.012227         0.013673        0.000505
#
#     param_bootstrap param_max_depth param_max_features  \
# 15             True              20               sqrt
# 14             True              20               sqrt
# 13             True              20               sqrt
# 5              True            None               sqrt
# 7              True            None               sqrt
# 12             True              20               sqrt
# 4              True            None               sqrt
# 3              True            None               sqrt
# 6              True            None               sqrt
# 11             True              20               sqrt
# 10             True              20               sqrt
# 2              True            None               sqrt
# 9              True              20               sqrt
# 1              True            None               sqrt
# 0              True            None               sqrt
# 8              True              20               sqrt
#
#     param_min_samples_leaf  param_min_samples_split  param_n_estimators  \
# 15                       2                        5                 100
# 14                       2                        5                  50
# 13                       2                        2                 100
# 5                        2                        2                 100
# 7                        2                        5                 100
# 12                       2                        2                  50
# 4                        2                        2                  50
# 3                        1                        5                 100
# 6                        2                        5                  50
# 11                       1                        5                 100
# 10                       1                        5                  50
# 2                        1                        5                  50
# 9                        1                        2                 100
# 1                        1                        2                 100
# 0                        1                        2                  50
# 8                        1                        2                  50
#
#                                                params  split0_test_score  \
# 15  {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.863662
# 14  {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.857689
# 13  {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.859216
# 5   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.855750
# 7   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.855440
# 12  {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.859831
# 4   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.852071
# 3   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.856044
# 6   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.852738
# 11  {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.853948
# 10  {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.852873
# 2   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.855270
# 9   {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.849461
# 1   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.847268
# 0   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.843841
# 8   {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.845385
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 15           0.836511           0.818390           0.848897
# 14           0.833988           0.814218           0.849302
# 13           0.832463           0.816101           0.846395
# 5            0.835953           0.819935           0.843027
# 7            0.831374           0.820360           0.846811
# 12           0.833498           0.814557           0.847216
# 4            0.832691           0.820276           0.849073
# 3            0.837053           0.813287           0.844286
# 6            0.827555           0.816762           0.845729
# 11           0.829662           0.814345           0.840813
# 10           0.825949           0.809198           0.841751
# 2            0.827232           0.814103           0.840436
# 9            0.828730           0.801904           0.837512
# 1            0.822624           0.799275           0.836555
# 0            0.823561           0.798105           0.830704
# 8            0.817882           0.798764           0.836254
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 15           0.780957         0.829683        0.028538                1
# 14           0.781345         0.827309        0.027333                2
# 13           0.782325         0.827300        0.026676                3
# 5            0.779930         0.826919        0.026188                4
# 7            0.780570         0.826911        0.026154                5
# 12           0.779224         0.826865        0.028164                6
# 4            0.779437         0.826710        0.026288                7
# 3            0.779758         0.826086        0.027052                8
# 6            0.777378         0.824032        0.026596                9
# 11           0.778553         0.823464        0.025957               10
# 10           0.781238         0.822202        0.025235               11
# 2            0.771850         0.821778        0.028465               12
# 9            0.769852         0.817492        0.028501               13
# 1            0.771621         0.815469        0.027173               14
# 0            0.767906         0.812823        0.026949               15
# 8            0.763611         0.812379        0.029166               16

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
